# %%
import numpy as np
import pandas as pd
import finpy_tse as tse
import mplfinance as mplf
import scipy.stats as stt
import matplotlib.pyplot as plt

# %%
DF2 = tse.Get_CWI_History(start_date='1396-01-01',
                          end_date='1402-06-05',
                          ignore_date=False,
                          just_adj_close=False,
                          show_weekday=True,
                          double_date=True)

# %%
DF2
# Out:
#                  Date    Weekday       Open       High        Low      Close  \
# J-Date
# 1396-01-05 2017-03-25   Saturday    77239.0    77494.0    77239.0    77486.0
# 1396-01-06 2017-03-26     Sunday    77505.0    77542.0    77493.0    77503.0
# 1396-01-07 2017-03-27     Monday    77519.0    77529.0    77481.0    77523.0
# 1396-01-08 2017-03-28    Tuesday    77533.0    77577.0    77533.0    77548.0
# 1396-01-09 2017-03-29  Wednesday    77575.0    77607.0    77565.0    77584.0
# ...               ...        ...        ...        ...        ...        ...
# 1402-05-29 2023-08-20     Sunday  1957480.0  1957480.0  1953450.0  1954030.0
# 1402-05-30 2023-08-21     Monday  1954410.0  1958680.0  1954410.0  1956441.0
# 1402-05-31 2023-08-22    Tuesday  1956200.0  1956200.0  1938220.0  1938248.0
# 1402-06-01 2023-08-23  Wednesday  1937970.0  1946630.0  1937950.0  1946594.0
# 1402-06-04 2023-08-26   Saturday  1950320.0  1993110.0  1950320.0  1993097.0
#
#             Adj Close      Volume
# ...

# %%
DF2['dailyReturn']=DF2['Close'].pct_change()

# %%
DF2
# Out:
#                  Date    Weekday       Open       High        Low      Close  \
# J-Date
# 1396-01-05 2017-03-25   Saturday    77239.0    77494.0    77239.0    77486.0
# 1396-01-06 2017-03-26     Sunday    77505.0    77542.0    77493.0    77503.0
# 1396-01-07 2017-03-27     Monday    77519.0    77529.0    77481.0    77523.0
# 1396-01-08 2017-03-28    Tuesday    77533.0    77577.0    77533.0    77548.0
# 1396-01-09 2017-03-29  Wednesday    77575.0    77607.0    77565.0    77584.0
# ...               ...        ...        ...        ...        ...        ...
# 1402-05-29 2023-08-20     Sunday  1957480.0  1957480.0  1953450.0  1954030.0
# 1402-05-30 2023-08-21     Monday  1954410.0  1958680.0  1954410.0  1956441.0
# 1402-05-31 2023-08-22    Tuesday  1956200.0  1956200.0  1938220.0  1938248.0
# 1402-06-01 2023-08-23  Wednesday  1937970.0  1946630.0  1937950.0  1946594.0
# 1402-06-04 2023-08-26   Saturday  1950320.0  1993110.0  1950320.0  1993097.0
#
# ...

# %%
DF2.index = DF2['Date']
mplf.plot(DF2[-200:],type="line", mav=(13, 55))
plt.show()

# %%
import asyncio
from fipiran.symbols import Symbol

async def main():
    company_info = await Symbol('فملی').company_info()
    print(company_info)

# %%
main()
# Out:
# <coroutine object main at 0x000001F5F6096DC0>

# %%
from fipiran.symbols import Symbol
await Symbol('فملی').company_info()
# Out:
# {'نام نماد': 'فملی',
#  'نام شرکت': 'ملی صنایع مس ایران',
#  'مدیر عامل': 'علی رستمی',
#  'تلفن': '021-88724410',
#  'فکس': '021-88729014',
#  'آدرس': 'مجتمع مس سرچشمه و مجتمع مس میدوک در استان کرمان و مجتمع مس سونگون در تبریز شهرستان ورزقان واقع شده اند.',
#  'وب سایت': 'www.nicico.com',
#  'ایمیل': 'office@nicico.com',
#  'سال مالی': '12/29',
#  'موضوع فعالیت': 'اکتشافات،  استخراج و  بهره برداری از معادن  مس  ایران'}

# %%
from fipiran.funds import funds
await funds()
# Out:
#      regNo                               name  rankOf12Month  rankOf24Month  \
# 0    11777    اختصاصی بازارگردانی آسمان زاگرس            NaN            NaN
# 1    11941      اختصاصی بازارگردانی آوای فراز            NaN            NaN
# 2    11950                   جسورانه سپهر یکم            NaN            NaN
# 3    11783  اختصاصی بازارگردانی گسترش نو ویرا            NaN            NaN
# 4    11446        اختصاصی بازارگردانی گروه دی            NaN            NaN
# ..     ...                                ...            ...            ...
# 399  11919       اختصاصی بازارگردانی یکم آسال            NaN            NaN
# 400  12081          جسورانه فناوری های تکاملی            NaN            NaN
# 401  12107    اختصاصی بازارگردانی پایش پایدار            NaN            NaN
# 402  12116         اختصاصی بازارگردانی برلیان            NaN            NaN
# 403  12124                     جسورانه ارغوان            NaN            NaN
#
# ...

# %%
data= await funds()

# %%
data
# Out:
#      regNo                               name  rankOf12Month  rankOf24Month  \
# 0    11777    اختصاصی بازارگردانی آسمان زاگرس            NaN            NaN
# 1    11941      اختصاصی بازارگردانی آوای فراز            NaN            NaN
# 2    11950                   جسورانه سپهر یکم            NaN            NaN
# 3    11783  اختصاصی بازارگردانی گسترش نو ویرا            NaN            NaN
# 4    11446        اختصاصی بازارگردانی گروه دی            NaN            NaN
# ..     ...                                ...            ...            ...
# 399  11919       اختصاصی بازارگردانی یکم آسال            NaN            NaN
# 400  12081          جسورانه فناوری های تکاملی            NaN            NaN
# 401  12107    اختصاصی بازارگردانی پایش پایدار            NaN            NaN
# 402  12116         اختصاصی بازارگردانی برلیان            NaN            NaN
# 403  12124                     جسورانه ارغوان            NaN            NaN
#
# ...

# %%
df = pd.DataFrame(data)

# %%
df.columns
# Out:
# Index(['regNo', 'name', 'rankOf12Month', 'rankOf24Month', 'rankOf36Month',
#        'rankOf48Month', 'rankOf60Month', 'rankLastUpdate', 'fundType',
#        'typeOfInvest', 'fundSize', 'initiationDate', 'dailyEfficiency',
#        'weeklyEfficiency', 'monthlyEfficiency', 'quarterlyEfficiency',
#        'sixMonthEfficiency', 'annualEfficiency', 'statisticalNav',
#        'efficiency', 'cancelNav', 'issueNav', 'dividendIntervalPeriod',
#        'guaranteedEarningRate', 'date', 'netAsset', 'estimatedEarningRate',
#        'investedUnits', 'articlesOfAssociationLink', 'prosoectusLink',
#        'websiteAddress', 'manager', 'managerSeoRegisterNo',
#        'guarantorSeoRegisterNo', 'auditor', 'custodian', 'guarantor', 'beta',
#        'alpha', 'isCompleted', 'fiveBest', 'stock', 'bond', 'other', 'cash',
#        'deposit', 'fundUnit', 'commodity', 'fundPublisher', 'smallSymbolName',
#        'insCode', 'fundWatch'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 52 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   regNo                      404 non-null    int64
#  1   name                       404 non-null    string
#  2   rankOf12Month              0 non-null      float64
#  3   rankOf24Month              0 non-null      float64
#  4   rankOf36Month              0 non-null      float64
#  5   rankOf48Month              0 non-null      float64
#  6   rankOf60Month              0 non-null      float64
#  7   rankLastUpdate             404 non-null    object
#  8   fundType                   404 non-null    int64
#  9   typeOfInvest               404 non-null    category
#  10  fundSize                   389 non-null    Int64
#  11  initiationDate             404 non-null    object
#  12  dailyEfficiency            389 non-null    float64
# ...

# %%
#df.set_index('regNo')
df['netAsset'].hist()
# Out:
# <AxesSubplot: >

# %%
df.describe(include='all').T
# Out:
#                            count unique  \
# regNo                      404.0    NaN
# name                         404    404
# rankOf12Month                0.0    NaN
# rankOf24Month                0.0    NaN
# rankOf36Month                0.0    NaN
# rankOf48Month                0.0    NaN
# rankOf60Month                0.0    NaN
# rankLastUpdate               404      1
# fundType                   404.0    NaN
# typeOfInvest                 404      2
# fundSize                   389.0   <NA>
# initiationDate               404    335
# dailyEfficiency            389.0    NaN
# weeklyEfficiency           389.0    NaN
# monthlyEfficiency          389.0    NaN
# quarterlyEfficiency        389.0    NaN
# sixMonthEfficiency         389.0    NaN
# annualEfficiency           389.0    NaN
# statisticalNav             389.0    NaN
# efficiency                 389.0    NaN
# cancelNav                  389.0    NaN
# issueNav                   389.0    NaN
# ...

# %%
df.sort_values('fundSize', ascending=False).head(50).plot.bar(x='name',y='fundSize', figsize=(10,5))
# Out:
# <AxesSubplot: xlabel='name'>

# %%
#import seaborn as sns
#plt.figure(figsize=(13,17))
#sns.pairplot(df)
#plt.show()
